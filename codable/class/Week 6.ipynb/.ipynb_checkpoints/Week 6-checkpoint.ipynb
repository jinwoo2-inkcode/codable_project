# %%
d = {'a':2, 'd':3, 'c':6}
d['a'] = 5
temp = d.pop('a')

d.update({'e':temp})
d
# Out:
# {'d': 3, 'c': 6, 'e': 5}

# %% [markdown]
# ## Data Visualization Basics

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
apple = pd.read_csv("aapl.csv")
type(apple)
apple
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-10-11   10.526428   10.615714   10.521428   10.548572    9.115436
# 1     2010-10-12   10.550357   10.696428   10.446072   10.662143    9.213575
# 2     2010-10-13   10.721429   10.784286   10.707143   10.719286    9.262955
# 3     2010-10-14   10.774643   10.802500   10.728572   10.796785    9.329926
# 4     2010-10-15   10.980000   11.250000   10.889643   11.240714    9.713540
# ...          ...         ...         ...         ...         ...         ...
# 2513  2020-10-05  113.910004  116.650002  113.550003  116.500000  116.500000
# 2514  2020-10-06  115.699997  116.120003  112.250000  113.160004  113.160004
# 2515  2020-10-07  114.620003  115.550003  114.129997  115.080002  115.080002
# 2516  2020-10-08  116.250000  116.400002  114.589996  114.970001  114.970001
# 2517  2020-10-09  115.279999  117.000000  114.919998  116.970001  116.970001
#
#          Volume
# 0     427753200
# ...

# %%
# Basic integer positioning

a = [1, 2, 3, 4]
a[1:]

apple.iloc[-5:, 0]
apple.iloc[-5:, -1]
# Out:
# 2513    106243800
# 2514    161498200
# 2515     96849000
# 2516     83477200
# 2517     99893400
# Name: Volume, dtype: int64

# %%
apple['Date'].to_list()
# Out:
# ['2010-10-11',
#  '2010-10-12',
#  '2010-10-13',
#  '2010-10-14',
#  '2010-10-15',
#  '2010-10-18',
#  '2010-10-19',
#  '2010-10-20',
#  '2010-10-21',
#  '2010-10-22',
#  '2010-10-25',
#  '2010-10-26',
#  '2010-10-27',
#  '2010-10-28',
#  '2010-10-29',
#  '2010-11-01',
#  '2010-11-02',
#  '2010-11-03',
#  '2010-11-04',
#  '2010-11-05',
#  '2010-11-08',
#  '2010-11-09',
#  '2010-11-10',
#  '2010-11-11',
#  '2010-11-12',
#  '2010-11-15',
#  '2010-11-16',
#  '2010-11-17',
#  '2010-11-18',
#  '2010-11-19',
#  '2010-11-22',
#  '2010-11-23',
#  '2010-11-24',
#  '2010-11-26',
#  '2010-11-29',
#  '2010-11-30',
#  '2010-12-01',
#  '2010-12-02',
#  '2010-12-03',
#  '2010-12-06',
#  '2010-12-07',
#  '2010-12-08',
#  '2010-12-09',
#  '2010-12-10',
#  '2010-12-13',
#  '2010-12-14',
#  '2010-12-15',
#  '2010-12-16',
#  '2010-12-17',
#  '2010-12-20',
#  '2010-12-21',
#  '2010-12-22',
#  '2010-12-23',
#  '2010-12-27',
#  '2010-12-28',
#  '2010-12-29',
#  '2010-12-30',
#  '2010-12-31',
# ...

# %%
# Exercise: Get the difference between the average of the first 100 rows and the last 100 rows of apple 'Close'
first100 = apple['Close'].iloc[:100]
last100 = apple['Close'].iloc[-100:]
abs(first100.mean() - last100.mean())
# Out:
# 90.79945319999999

# %%
 # Basic label positioning
bobas = pd.DataFrame([[6, 7], [8, 6], [7, 5]], index = ['Coco Mero', 'Teamoji', 'Kung Foo Tea'], columns = ['Taste', 'Price'])
bobas

bobas.iloc[1, 0]
bobas.loc['Teamoji', 'Taste']

bobas.iloc[1, 0] == bobas.loc['Teamoji', 'Taste']


apple.loc[1, 'Open'] == apple.iloc[1, 1]
# Out:
# True

# %%
# Basic filtering

apple[apple['Close'] > 110]
# apple.iloc[2475]
apple[(apple['Close'] > 110) & (apple['High'] < 115)]['Date']
# Out:
# 2471    2020-08-05
# 2472    2020-08-06
# 2473    2020-08-07
# 2474    2020-08-10
# 2476    2020-08-12
# 2501    2020-09-17
# 2503    2020-09-21
# 2504    2020-09-22
# 2507    2020-09-25
# Name: Date, dtype: object

# %%
# Exercise: Among the rows where 'High' is less than 100 and 'Low' is greater than 80, find the maximum of 'Open'
max(apple[(apple['High'] < 100) & (apple['Low'] > 80)]['Open'])
# Out:
# 99.172501

# %%
# Data visualization basics
plt.plot(apple['Close'])

# %%
plt.plot(apple['Date'], apple['Close'])

# %%
type(apple['Date'].iloc[0])
apple['Date'] = pd.to_datetime(apple['Date'])
type(apple['Date'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
plt.figure(figsize = (20, 10))
plt.plot(apple['Date'], apple['Close'])
plt.title('Apple Stock Closing Price')
plt.xlabel("Date")
plt.ylabel("Stock Price($)")
# Out:
# Text(0, 0.5, 'Stock Price($)')

# %%
# pip install ipympl
# %matplotlib widget

# %%
plt.figure(figsize = (10, 5))
plt.plot(apple['Date'], apple['Close'])
plt.title('Apple Stock Closing Price')
plt.xlabel("Date")
plt.ylabel("Stock Price($)")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0, 0.5, 'Stock Price($)')

# %%
google = pd.read_csv('goog.csv')
google['Date'] = pd.to_datetime(google['Date'])

# %%
plt.figure(figsize = (10, 5))
plt.plot(apple['Date'], apple['Close'], label = "Apple")
plt.plot(google['Date'], google['Close'], label = "Google")
plt.title('Apple vs Google Stock Closing Price')
plt.xlabel("Date")
plt.ylabel("Stock Price($)")
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
a_close = apple['Close'].to_list()
g_close = google['Close'].to_list()
a_start, g_start = a_close[0], g_close[0]
a_close = [(i - a_start)/a_start * 100 for i in a_close]
g_close = [(i - g_start)/g_start * 100 for i in g_close]
apple['Close Scaled'] = a_close
google['Close Scaled'] = g_close
apple
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-10-11   10.526428   10.615714   10.521428   10.548572    9.115436
# 1    2010-10-12   10.550357   10.696428   10.446072   10.662143    9.213575
# 2    2010-10-13   10.721429   10.784286   10.707143   10.719286    9.262955
# 3    2010-10-14   10.774643   10.802500   10.728572   10.796785    9.329926
# 4    2010-10-15   10.980000   11.250000   10.889643   11.240714    9.713540
# ...         ...         ...         ...         ...         ...         ...
# 2513 2020-10-05  113.910004  116.650002  113.550003  116.500000  116.500000
# 2514 2020-10-06  115.699997  116.120003  112.250000  113.160004  113.160004
# 2515 2020-10-07  114.620003  115.550003  114.129997  115.080002  115.080002
# 2516 2020-10-08  116.250000  116.400002  114.589996  114.970001  114.970001
# 2517 2020-10-09  115.279999  117.000000  114.919998  116.970001  116.970001
#
#          Volume  Close Scaled
# ...

# %%
plt.figure(figsize = (10, 5))
plt.plot(apple['Date'], apple['Close Scaled'], label = "Apple")
plt.plot(google['Date'], google['Close Scaled'], label = "Google")
plt.title('Apple vs Google Change in Stock Closing Price')
plt.xlabel("Date")
plt.ylabel("Percentage (%)")
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
